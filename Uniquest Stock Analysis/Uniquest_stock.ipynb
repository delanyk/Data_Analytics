# %% [markdown]
# # Uniquest Stock Record

# %%
import datetime as dt
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import style
import pandas_datareader as web

# %%
style.use('ggplot')
# start = dt.datetime(2000,1,1)
# end = dt.datetime(2017,7,30)
# df = web.DataReader('KRX:077500', 'google', start, end)

# %%
# print(df.tail(10))

# %%
# df.to_csv('uniquest.csv')

# %%
df = pd.read_csv('uniquest.csv', parse_dates=True, index_col=0)

# %%
df['Close'].plot()
plt.show()

# %%
df['100ma'] = df['Close'].rolling(window=100, min_periods = 0).mean()

# %%
print(df.head())
print(df.tail())
# Out:
#               Open    High     Low   Close   Volume        100ma
# Date
# 2004-08-05  1727.0  1736.0  1545.0  1627.0  1874312  1627.000000
# 2004-08-06  1636.0  1727.0  1591.0  1607.0   396543  1617.000000
# 2004-08-09  1636.0  1655.0  1582.0  1586.0    93227  1606.666667
# 2004-08-10  1555.0  1582.0  1364.0  1455.0   242735  1568.750000
# 2004-08-11  1484.0  1673.0  1484.0  1673.0   935081  1589.600000
#               Open    High     Low   Close   Volume   100ma
# Date
# 2017-07-10  7410.0  7500.0  7120.0  7400.0   289658  7063.9
# 2017-07-11  7500.0  8230.0  7370.0  8180.0  1473203  7084.4
# 2017-07-12  8180.0  8420.0  8100.0  8330.0   829851  7105.6
# 2017-07-13  8350.0  8430.0  8140.0  8210.0   458669  7127.1
# 2017-07-14  8250.0  8340.0  8090.0  8240.0   394935  7148.9

# %%
ax1 = plt.subplot2grid((6,1), (0,0), rowspan=5, colspan=1)
ax2 = plt.subplot2grid((6,1), (5,0), rowspan=1, colspan=1, sharex=ax1)

# %%
ax1.plot(df.index, df['Close'])
ax1.plot(df.index, df['100ma'])
ax2.bar(df.index, df['Volume'])
plt.show()
